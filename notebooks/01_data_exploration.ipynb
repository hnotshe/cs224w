# %% [markdown]
# # 01 Data Exploration
# Initial sanity checks and exploratory plots for regional features.

# %%
import pandas as pd
from pathlib import Path

data_dir = Path('..') / 'data' / 'raw'
list(data_dir.iterdir())
