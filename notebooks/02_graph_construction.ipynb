# %% [markdown]
# # 02 Graph Construction
# Build the region adjacency graph and inspect connectivity.

# %%
import scipy.sparse as sp
from pathlib import Path

adjacency_path = Path('..') / 'data' / 'processed' / 'adjacency.npz'
sp.load_npz(adjacency_path)
