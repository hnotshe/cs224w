# %% [markdown]
# # 03 GCN Training
# Train and evaluate the suitability prediction model.

# %%
# !../run.sh --features ../data/processed/regions.csv --adjacency ../data/processed/adjacency.npz --target-column suitability_score
